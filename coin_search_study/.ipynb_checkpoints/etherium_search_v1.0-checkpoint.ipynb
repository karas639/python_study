# %% [markdown]
# ## etherium search crolling
# - 일반 ui 검색과 api 검색, web3를 이용한 트랜잭션 조회 데이터를 비교하여 정합성 검증
# - web 서비스 또는 파이썬 cli 도구 또는 gui로 구현
# - 조회 결과에서 n차 검색이 가능하게 하여 최종 목적지 추적 및 시각화 가능
# - 최종 목적지 유형 별 분류 및 포렌식 및 수사에 있어 의미있는 데이터 추출
# - github 소스 관리

# %% [markdown]
# ### 1. data crolling test

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

input_data = input("Search by Address : ").lower() # etherium 주소를 입력받고 소문자 치환
URL = f"https://etherscan.io/address/{input_data}" # etherscan.io 주소 URL 변수에 선언
#URL = "https://etherscan.io/address/0x6b50911190cffd34b50d575706639c24aafdc625"
print(URL + "\n" + "-"*70) # -*70줄 프린트

headers = {'User-Agent': 'Mozilla/5.0'} # header 선언, http 요청 브라우저는 Mozilla.
resp = requests.get(URL, headers=headers) # http get 요청을 resp 변수에 선언
print(resp) # 요청 프린트
print(URL + "\n" + "-"*70) # -*70줄 프린트

# parameter 전달법 확인
params = {'key':'value'}
res = requests.get(URL, params=params)
res.url
print(URL + "\n" + "-"*70) # -*70줄 프린트

im = BeautifulSoup(resp.text, 'html.parser') #세션을 가져와서 html을 text로 parsing, im 변수에 선언
tag = im.find_all(attrs={'class':'hash-tag text-truncate'}) #im 변수에서 hash-tag text-truncate class를 저장
print(tag) #가공되지 않은 크롤링 값 출력
# Out:
# Search by Address : fd
# https://etherscan.io/address/fd
# ----------------------------------------------------------------------
# <Response [200]>
# https://etherscan.io/address/fd
# ----------------------------------------------------------------------
# https://etherscan.io/address/fd
# ----------------------------------------------------------------------
# []

# %% [markdown]
# ### 1-1. ethereum api키를 이용하여 트랜잭션 조회하기
# #### 이더스캔에서 주소를 조회해보면 왼쪽상단에 Contract 라고 기재되어있으면 CA , Address라고 적혀 있다면 EOA 입니다. 또한 바로 하단에 CA의 경우 Contract Overview, EOA는 Overview라고 기재되어 있습니다. 게다가 CA는 이더스캔에서 ContractCreator 정보가 함께 기재되어 누가 언제 만들었는지도 알 수 있습니다.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import json
from collections import ChainMap

apikey = "WP3JPWBB21D6JRN1AVIE451N4H5YVTJN4M"
addr = input("Search by Address : ").lower() # etherium 주소를 입력받고 소문자 치환

# ethereum api - etherscan.io/apis
# Ropsten - Testnet Network  - ropsten.etherscan.io/apis
# get ether "Balance" for a single Address
#URL = f"https://api.etherscan.io/api?module=account&action=balance&address={addr}&tag=latest&apikey={apikey}" 

# get ether "Balance" for multiple addresses in a single call, 여러 주소 입력 및 검색
#URL2 = f"https://api.etherscan.io/api?module=account&action=balancemulti&address={addr}{addr}{addr}&tag=latest&apikey={apikey}" 

# get a list of 'Normal' Transactions By address (Asc)
#URL3 = f"https://api.etherscan.io/api?module=account&action=txlist&address={addr}&startblock=0&endblock=99999999&sort=asc&apikey={apikey}"

# get a list of 'Normal' Transactions By address (Desc)
URL4 = f"http://api.etherscan.io/api?module=account&action=txlist&apikey={apikey}&sort=desc&address={addr}"

#print(URL + "\n" + "-"*70) # -*70줄 프린트
#print(URL2 + "\n" + "-"*70) # -*70줄 프린트
#print(URL3)
print(URL4)

headers = {'User-Agent': 'Mozilla/5.0'} # header 선언, http 요청 브라우저는 Mozilla.
resp = requests.get(URL4).json() # http get 요청을 resp 변수에 선언
data = resp["result"]
print(data[0-10000]['blockNumber'])

# 리스트안에 딕셔너리 정렬 예 --> sorted(iterable, key=None, reverse=False)
#result_data = sorted(data, key=lambda x:x['blockNumber'], reverse=True)
#print(result_data)

#cm = ChainMap(*data)
#cm['blockNumber']


# 리스트 안에 딕셔너리임, 키 밸류 키 밸류 여기서 키만 추출
# Out:
# Search by Address : 0xE242271f229E4A7e3F3D555d5B0F86A412F24123
# http://api.etherscan.io/api?module=account&action=txlist&apikey=WP3JPWBB21D6JRN1AVIE451N4H5YVTJN4M&sort=desc&address=0xe242271f229e4a7e3f3d555d5b0f86a412f24123
# 11541201

# %% [markdown]
# - # 참고 URL
# - ethereum developers apis - https://ropsten.etherscan.io/apis#accounts
# - https://jonelove.tistory.com/entry/%EC%9D%B4%EB%8D%94%EB%A6%AC%EC%9B%80-%ED%8A%B8%EB%9E%9C%EC%9E%AD%EC%85%98-%EB%A1%9C%EA%B7%B8-%EA%B0%80%EC%A0%B8%EC%98%A4%EA%B8%B0
# - 파이썬 웹에서 json 가져오기 - https://okhee.co.kr/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%9B%B9%EC%97%90%EC%84%9C-json-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EA%B0%80%EC%A0%B8%EC%98%A4%EA%B8%B0/
# - https://chchy.tistory.com/345
# - http://blockchaindev.kr/models/content/86
# - https://hogni.tistory.com/116
# - https://hashcode.co.kr/questions/4802/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EB%A6%AC%EC%8A%A4%ED%8A%B8-%EC%86%8D-%EB%94%95%EC%85%94%EB%84%88%EB%A6%AC-%ED%98%95%ED%83%9C%EC%97%90-%EC%9A%94%EC%86%8C%EC%97%90%EC%84%9C-%EC%9B%90%ED%95%98%EB%8A%94-%EB%B0%B8%EB%A5%98-%EA%B0%92-%EC%B0%BE%EA%B8%B0

# %% [markdown]
# ### 2. etherium search v1.0_backup

# %%
#!/usr/bin/env python3

import requests
from bs4 import BeautifulSoup
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
from matplotlib import pyplot as plt
import chart_studio.plotly as py

"""def ADDR(eth_addr_text):
    input_data = input("Search by Address : ")
    data_trans = input_data.lower()
"""

# 2019.08.27 backup
# 함수선언, eth 주소 값을 입력 받아 csv에 컬럼별로 저장하는 함수
def URL_search(eth_addr_text):
    input_data = input("Search by Address : ").lower()  # 주소값을 입력받고 소문자로 치환
    URL = f"https://etherscan.io/address/{input_data}"  # 입력받은 주소값을 ethscan을 통해 검색, 변수 저장
    print(URL + "\n" + "-"*70)                          # 검색한 URL을 출력
    resp = requests.get(URL)
    print(resp)
    sess = requests.Session()
    im = BeautifulSoup(sess.get(URL).text, 'html.parser')
    tag = im.find_all(attrs={'class':'hash-tag text-truncate'})
    f = open('etherscan_search1.csv', mode='w')                        
    f.write("IN/OUT,from,from_addr,to,to_addr" + "\n")
    print(tag)
    i = 0
    for tags in tag :
        if len(tags.text) < 43 :
                list_i = tags.text
                if (i % 2) == 0 :
                    if list_z == input_data :
                        result1 = f"OUT, from, {list_z}, to, {list_i}"
                        f.write(result1 + "\n")
                    else:
                        result2 = f"IN , from, {list_z}, to, {list_i}"
                        f.write(result2 + "\n")
                    i = i + 1
                else :
                        list_z = list_i
        i = i + 1
    f.close()

URL_search("")
df = pd.read_csv('etherscan_search1.csv', engine='python')
df_dup = df.drop_duplicates()
#b = df_dup['to_addr']
f1 = open('etherscan_search2.csv', mode='w')
f1.close
print (df_dup['to_addr'])


for row in df_dup.itertuples():
    print (row.to_addr)
    x = row.to_addr
    y = str(x)
    #y = f1.write(x + "\n")
    z = open('etherscan_search2.csv', mode='r')
    line = 'init'
    #while line:
    #    line = y.readlines()
    #    URL_search(f"{line}")
    #print (x)
    URL_search(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4d80e71ead40> in <module>
#       7 import numpy as np
#       8 from matplotlib import pyplot as plt
# ----> 9 import chart_studio.plotly as py
#      10
#      11 """def ADDR(eth_addr_text):
#
# ModuleNotFoundError: No module named 'chart_studio'

# %% [markdown]
# ### 3. etherium search v1.0

# %%
#!/usr/bin/env python3

import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
#import chart_studio.plotly as py
import sys, csv, datetime, os, re, json

now = datetime.datetime.now()
nowDate = now.strftime('%Y-%m-%d')
nowTime = now.strftime('%H:%M:%S')
'''
def showmenu():
    print()
    print("[Cryptocurrency address search choose menu]")
    for i in range(0, len(menu)):
        print(i+1, ".", menu[i])
    print()
'''

BASE_DIR = os.path.dirname(os.path.abspath(__file__))   
# 함수선언, eth 주소 값을 입력 받아 csv에 컬럼별로 저장하는 함수
def eth_search(eth_addr_text):
    input_data = input("Search by Address : ").lower()
    URL = f"https://etherscan.io/address/{input_data}"
    print(URL + "\n" + "-"*70)
    headers = {'User-Agent': 'Mozilla/5.0'}
    sess = requests.Session()
    resp = sess.get(URL, headers=headers)
    html = resp.text    # HTML source 
    soup = BeautifulSoup(html, 'html.parser')
    etherscan = soup.select(
        '#transactions > div.table-responsive.mb-2.mb-md-0 > table > tbody > tr > td > a'
    )
    print(etherscan)
    '''for title in etherscan:
        print(title.text) ## tag안의 텍스트
        print(title.get('href')) ## tag의 속성을 가져오기(ex: href속성)
        hrefget = title.get('href')
        regex = re.compile('(?<=address/)0x.{40}', re.IGNORECASE | re.VERBOSE)
        mc = regex.findall(hrefget)
        for x in mc:
            print(x)
            #sys.stdout = open(os.path.join(BASE_DIR, 'output.txt'),'w')


def toJson(addr_list):
    with open(os.path.join(BASE_DIR, f'result_{nowDate}.json'), 'a', encoding='utf-8') as json_file:
        json.dump(addr_list, json_file, ensure_ascii=False, indent='\t')

addr_list = []
toJson(addr_list)


def dataframe():
    df = pd.read_csv(f'etherscan_search_{nowDate}.csv', engine='python')
    df_dup = df.drop_duplicates()
    x = df_dup.itertuples()
    
    for row in x:
        print(row.to_addr)

'''
eth_search("")


'''
if __name__ == '__main__':
    menu = ("Bitcoin", "ethereum", "Bitcash", "ada")
    #number = (1, 2, 3, 4)
    #money = 0
    #money = int( input("돈을 투입하세요 : ") )

    while True:
        showmenu()
        sel = int(input("Choose Menu number (Exit 0) : "))
        if sel == 0:
            break
        elif(sel>=1 and sel <= len(menu)):
            eth_search("")
            print ("duplicate OUT address print")
            dataframe()
            sel1 = str(input("[*] Do you want to continue searching? : "))
            if sel1 == "no":
                break
            elif sel1 == "yes":
                print ("keep going")
                eth_search("")
                dataframe()
                sel1 = str(input("[*] Do you want to continue searching? : "))
                
            else : 
                print ("quit")
        else:
            print("잘못된 메뉴 번호입니다.")
    print ("complete search")

'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-86f86bca29ff> in <module>
#      21 '''
#      22
# ---> 23 BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#      24 # 함수선언, eth 주소 값을 입력 받아 csv에 컬럼별로 저장하는 함수
#      25 def eth_search(eth_addr_text):
#
# NameError: name '__file__' is not defined

# %% [markdown]
# ### 4. etherium search v1.0-2

# %%
#!/usr/bin/env python3

import requests 
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import chart_studio.plotly as py
import csv
import datetime
import os

now = datetime.datetime.now()
nowDate = now.strftime('%Y-%m-%d')
nowTime = now.strftime('%H:%M:%S')

# 메뉴 선택 함수
def showmenu():
    print()
    print("[Cryptocurrency address search choose menu]")
    for i in range(0, len(menu)):
        print(i+1, ".", menu[i])
    print()

# 결과를 저장할 csv 파일 지정
f = open(f'etherscan_search_{nowDate}.csv', mode='w')                        
f.write("Date,Time,IN/OUT,from,from_addr,to,to_addr" + "\n")
f.close() 

# 함수선언, eth 주소 값을 입력 받아 csv에 컬럼별로 저장하는 함수
def eth_search(eth_addr_text):
    input_data = input("Search by Address : ").lower()
    URL = f"https://etherscan.io/address/{input_data}"
    print(URL + "\n" + "-"*70)
    headers = {'User-Agent': 'Mozilla/5.0'}
    resp = requests.get(URL, headers=headers)
    #sess = requests.Session()
    #im = BeautifulSoup(sess.get(URL).text, 'html.parser')
    im = BeautifulSoup(resp.text, 'html.parser')
    tag = im.find_all(attrs={'class':'hash-tag text-truncate'})
    f = open(f'etherscan_search_{nowDate}.csv', mode='+a')
    i = 0
    for tags in tag :
        if len(tags.text) < 43 :
                list_i = tags.text
                print(list_i)
                print(URL + "\n" + "-"*70)
                if (i % 2) == 0 :
                    if list_z == input_data :
                        result1 = f"{nowDate}, {nowTime}, OUT , from, {list_z}, to, {list_i}"
                        # OUT만 파일에 저장
                        f.write(result1 + "\n")
                    else:
                        result2 = f"{nowDate}, {nowTime}, IN , from, {list_z}, to, {list_i}"
                        # IN은 파일에 저장하지 않음
                        #f.write(result2 + "\n")
                    i = i + 1
                else :
                        list_z = list_i
        i = i + 1
    f.write("-"*70 + "\n")
    f.close()
#eth_search("")

def dataframe():
    df = pd.read_csv(f'etherscan_search_{nowDate}.csv', engine='python')
    df_dup = df.drop_duplicates()
    x = df_dup.itertuples()
    
    for row in x:
        print(row.to_addr)

def search_loop():
    for i in range(10):
        for y in range(i+1):
            eth_search("")
            dataframe()

if __name__ == '__main__':
    menu = ("Bitcoin", "ethereum", "Bitcash", "ada")
    #number = (1, 2, 3, 4)
    #money = 0
    #money = int( input("돈을 투입하세요 : ") )

    while True:
        showmenu()
        sel = int(input("Choose Menu number (Exit 0) : "))
        if sel == 0:
            break
        elif(sel>=1 and sel <= len(menu)):
            eth_search("")
            print ("duplicate OUT address print")
            dataframe()
            sel1 = str(input("[*] Do you want to continue searching? : "))
            if sel1 == "no":
                break
            elif sel1 == "yes":
                print ("keep going")
                search_loop()
                """for x in sel1:
                    print (sel1)
                    if x == "no":
                        break
                    elif x == sel1:
                        sel1 = str(input("[*] Do you want to continue searching? : "))
                        eth_search("")
                        dataframe()
                    else:
                        print("quit")"""
            else : 
                print ("quit")
        else:
            print("잘못된 메뉴 번호입니다.")
    print ("complete search")


## 무한루프 검색 완료
## etherscan 주소 검색 시 OUT 트랜잭션이 없을 경우 오류 발생없이 자연스럽게 프로그램 종료 하는 코드 추가
